# %%
with open(r'D:\Data Science\justo.txt', 'r', encoding='utf-8') as f:
    txt = f.readlines()
f.close()

# %%
txt
# Out:
# ['BAGAIMANA 1MDB KANTOI - SKANDAL KEWANGAN TERBESAR DI DUNIA\n',
#  '\n',
#  'Pada 22 Jun 2015, Xavier Justo, bekas pegawai bank Swiss berjalan menuju ke pintu hadapan hotel butik baru miliknya di Koh Samui, sebuah pulau tropika Thailand. Dia telah menghabiskan masanya sejak tiga tahun lalu untuk mendirikan kompleks chalet dan apartmen mewah yang dibina menghadap laut. Justo mahu memulakan operasi hotelnya namun dia masih belum memiliki lesen.\n',
#  '\n',
# ...

# %%
txt = [singletxt for singletxt in txt if singletxt != '\n']

# %%
txt
# Out:
# ['BAGAIMANA 1MDB KANTOI - SKANDAL KEWANGAN TERBESAR DI DUNIA\n',
#  'Pada 22 Jun 2015, Xavier Justo, bekas pegawai bank Swiss berjalan menuju ke pintu hadapan hotel butik baru miliknya di Koh Samui, sebuah pulau tropika Thailand. Dia telah menghabiskan masanya sejak tiga tahun lalu untuk mendirikan kompleks chalet dan apartmen mewah yang dibina menghadap laut. Justo mahu memulakan operasi hotelnya namun dia masih belum memiliki lesen.\n',
# ...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sentence = sent_tokenize(txt[1])
sentence
# Out:
# ['Pada 22 Jun 2015, Xavier Justo, bekas pegawai bank Swiss berjalan menuju ke pintu hadapan hotel butik baru miliknya di Koh Samui, sebuah pulau tropika Thailand.',
#  'Dia telah menghabiskan masanya sejak tiga tahun lalu untuk mendirikan kompleks chalet dan apartmen mewah yang dibina menghadap laut.',
#  'Justo mahu memulakan operasi hotelnya namun dia masih belum memiliki lesen.']

# %%
words = word_tokenize(sentence[0])
words
# Out:
# ['Pada',
#  '22',
#  'Jun',
#  '2015',
#  ',',
#  'Xavier',
#  'Justo',
#  ',',
#  'bekas',
#  'pegawai',
#  'bank',
#  'Swiss',
#  'berjalan',
#  'menuju',
#  'ke',
#  'pintu',
#  'hadapan',
#  'hotel',
#  'butik',
#  'baru',
#  'miliknya',
#  'di',
#  'Koh',
#  'Samui',
#  ',',
#  'sebuah',
#  'pulau',
#  'tropika',
#  'Thailand',
#  '.']
